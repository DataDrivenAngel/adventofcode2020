# %%
text = open("5-input.txt",'r')
inpt = text.read().split('\n')

# %%
inpt
# Out:
# ['BBBFBFFRLL',
#  'FBBBBBFRRR',
#  'FBFFBBBRLR',
#  'FBBFBFBRLR',
#  'BBFBBFBLRL',
#  'BBFBFBBLLL',
#  'BBBBFFFRLL',
#  'FBBFFFBRRL',
#  'BFBFFBBRLL',
#  'BFFBFBBRLL',
#  'BBFFFBFRLR',
#  'FFBFBBBRRL',
#  'BBFFBFFLRL',
#  'FFBBBFFRLR',
#  'BFFFBFFRRL',
#  'BBFBFFFRRL',
#  'FBBFFFFRLL',
#  'FBBFFFBLRL',
#  'FBFFFFFRRR',
#  'FBBBFBFRLR',
#  'BFFBFFFRLR',
#  'BFBBBBFLLR',
#  'BBBBFFBLLR',
#  'FFFBBFFRRL',
#  'BBFBBFBLLL',
#  'BFBFBFBLRL',
#  'FFBBBFBLLR',
#  'FFFBFBFLRL',
#  'FBFBFBFLLL',
#  'FBBBFFBLLR',
#  'FBFBBFBLLR',
#  'FFFBFFFRLR',
#  'BFBBBFFRRL',
#  'FBFBBBBRLL',
#  'FBFFBFFLLR',
#  'BFFFFBFRLL',
#  'BFFBBFFRLL',
#  'FFBFBFFLLL',
#  'FFBBFFBRRR',
#  'BFFBBFBLLL',
#  'BBFBFBFLRL',
#  'BFBFFBFLRR',
#  'BFBBBFBRLL',
#  'FBBFFFFRRL',
#  'FFFBBBFLLL',
#  'FFBBBBFLLR',
#  'BBFBBFFRRL',
#  'BBFBBBFLLR',
#  'BBBFBFBLRR',
#  'BBFFFFFLRR',
#  'BFFBFFBLLR',
#  'FFFBFBFRLL',
#  'FBBBBFFRLR',
#  'BFBBBFFRRR',
#  'FBFFFFFRLR',
#  'BBFBBFFLRL',
#  'BBFFBFFLLR',
#  'FFBBBFBLRR',
# ...
